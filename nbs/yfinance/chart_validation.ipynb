# %%
import plotly.io as pio
pio.renderers.default = "notebook"  # or "jupyterlab", "iframe", "vscode", "colab"

# %%
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv
import os

load_dotenv("../../.env")

# 1. Define your PostgreSQL credentials
DATABASE_URL = os.getenv("POSTGRES_URL")

# 2. Create the SQLAlchemy connection engine
engine = create_engine(DATABASE_URL)

query = text("SELECT * FROM ohlcv_1d WHERE symbol = 'AAPL'")

# 3. Establish a connection block and read the data
with engine.connect() as connection:
    df = pd.read_sql_query(query, con=connection)

df
# Out:
#            date symbol   Adj Close       Close  Dividends        High  \
# 0    2000-01-03   AAPL    0.837724    0.999442        0.0    1.004464
# 1    2000-01-04   AAPL    0.767096    0.915179        0.0    0.987723
# 2    2000-01-05   AAPL    0.778321    0.928571        0.0    0.987165
# 3    2000-01-06   AAPL    0.710966    0.848214        0.0    0.955357
# 4    2000-01-07   AAPL    0.744644    0.888393        0.0    0.901786
# ...         ...    ...         ...         ...        ...         ...
# 6662 2025-05-13   AAPL  212.088608  212.929993        0.0  213.399994
# 6663 2025-05-14   AAPL  211.490982  212.330002        0.0  213.940002
# 6664 2025-05-15   AAPL  210.614456  211.449997        0.0  212.960007
# 6665 2025-05-16   AAPL  210.425201  211.259995        0.0  212.570007
# 6666 2025-05-19   AAPL  207.955002  208.779999        0.0  209.479996
#
#              Low        Open  Stock Splits       Volume    run_date  \
# ...

# %%
import plotly.graph_objects as go

data = df
# 2. Create the figure
fig = go.Figure(data=[go.Candlestick(
    x=data['date'],
    open=data['Open'],
    high=data['High'],
    low=data['Low'],
    close=data['Close']
)])

# 3. Customize and show the chart
fig.update_layout(title='AAPL - Interactive Candlestick Chart', yaxis_title='Price (USD)')
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="87604843-49b6-4991-8e3b-1ce09e83512f" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("87604843-49b6-4991-8e3b-1ce09e83512f")) {                    Plotly.newPlot(                        "87604843-49b6-4991-8e3b-1ce09e83512f",                        [{"close":{"dtype":"f8","bdata":"AAAAwG377z8AAACAJUntPwAAAIDatu0\u002fAAAAoJEk6z8AAAAgt23sPwAAACC37es\u002fAAAAAACA6j8AAAAAJenoPwAAAKCRpOs\u002fAAAAYEiy7D8AAABgSLLtPwAAAGBJcu4\u002fAAAAoNs28D8AAACgt83vPwAAAGBuW+4\u002fAAAAYCQJ8D8AAADAbXvvPwAAACC3be8\u002fAAAAYCQJ
# ...

# %%
fig
